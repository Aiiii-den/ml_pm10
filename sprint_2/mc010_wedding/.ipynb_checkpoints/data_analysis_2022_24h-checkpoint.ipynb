# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import json

file_path = os.path.join("air_berlin","2022_24h_mc010.json") # join because different os use either \ or / as file path seperators
df = pd.read_json(file_path)
df
# Out:
#                        datetime station  core component period  value
# 0     2022-12-31T00:00:00+01:00   mc010  pm10  pm10_24h    24h    9.0
# 1     2022-12-31T00:00:00+01:00   mc010   pm2   pm2_24h    24h    6.0
# 2     2022-12-31T00:00:00+01:00   mc010   no2   no2_24h    24h    9.0
# 3     2022-12-31T00:00:00+01:00   mc010    no    no_24h    24h    2.0
# 4     2022-12-31T00:00:00+01:00   mc010   nox   nox_24h    24h   13.0
# ...                         ...     ...   ...       ...    ...    ...
# 2185  2022-01-01T00:00:00+01:00   mc010   pm2   pm2_24h    24h   15.0
# 2186  2022-01-01T00:00:00+01:00   mc010   no2   no2_24h    24h   19.0
# 2187  2022-01-01T00:00:00+01:00   mc010    no    no_24h    24h    3.0
# 2188  2022-01-01T00:00:00+01:00   mc010   nox   nox_24h    24h   24.0
# 2189  2022-01-01T00:00:00+01:00   mc010    o3    o3_24h    24h   34.0
#
# [2190 rows x 6 columns]

# %%
df_sorted = df.sort_values(by='datetime')

# %%
df.sort_values(by='datetime').tail(10)
# Out:
#                     datetime station  core component period  value
# 9  2022-12-30T00:00:00+01:00   mc010    no    no_24h    24h    3.0
# 8  2022-12-30T00:00:00+01:00   mc010   no2   no2_24h    24h   16.0
# 7  2022-12-30T00:00:00+01:00   mc010   pm2   pm2_24h    24h    6.0
# 6  2022-12-30T00:00:00+01:00   mc010  pm10  pm10_24h    24h    9.0
# 5  2022-12-31T00:00:00+01:00   mc010    o3    o3_24h    24h   44.0
# 4  2022-12-31T00:00:00+01:00   mc010   nox   nox_24h    24h   13.0
# 3  2022-12-31T00:00:00+01:00   mc010    no    no_24h    24h    2.0
# 2  2022-12-31T00:00:00+01:00   mc010   no2   no2_24h    24h    9.0
# 1  2022-12-31T00:00:00+01:00   mc010   pm2   pm2_24h    24h    6.0
# 0  2022-12-31T00:00:00+01:00   mc010  pm10  pm10_24h    24h    9.0

# %%
df.sort_values(by='datetime').head(10)
# Out:
#                        datetime station  core component period  value
# 2189  2022-01-01T00:00:00+01:00   mc010    o3    o3_24h    24h   34.0
# 2184  2022-01-01T00:00:00+01:00   mc010  pm10  pm10_24h    24h   18.0
# 2185  2022-01-01T00:00:00+01:00   mc010   pm2   pm2_24h    24h   15.0
# 2188  2022-01-01T00:00:00+01:00   mc010   nox   nox_24h    24h   24.0
# 2187  2022-01-01T00:00:00+01:00   mc010    no    no_24h    24h    3.0
# 2186  2022-01-01T00:00:00+01:00   mc010   no2   no2_24h    24h   19.0
# 2183  2022-01-02T00:00:00+01:00   mc010    o3    o3_24h    24h   38.0
# 2182  2022-01-02T00:00:00+01:00   mc010   nox   nox_24h    24h   14.0
# 2181  2022-01-02T00:00:00+01:00   mc010    no    no_24h    24h    2.0
# 2180  2022-01-02T00:00:00+01:00   mc010   no2   no2_24h    24h   12.0

# %%
df['core'].value_counts()
# Out:
# core
# pm10    365
# pm2     365
# no2     365
# no      365
# nox     365
# o3      365
# Name: count, dtype: int64

# %%
df_pm10 = df[(df["core"] == "pm10")]
#& (df["datetime"].astype(str).str.contains("20:00:00"))]
df_pm10.count()
# Out:
# datetime     365
# station      365
# core         365
# component    365
# period       365
# value        364
# dtype: int64

# %%
df_pm10.sample(5)
# Out:
#                        datetime station  core component period  value
# 1698  2022-03-23T00:00:00+01:00   mc010  pm10  pm10_24h    24h   50.0
# 78    2022-12-18T00:00:00+01:00   mc010  pm10  pm10_24h    24h   25.0
# 2166  2022-01-04T00:00:00+01:00   mc010  pm10  pm10_24h    24h    7.0
# 1380  2022-05-15T00:00:00+02:00   mc010  pm10  pm10_24h    24h   11.0
# 1344  2022-05-21T00:00:00+02:00   mc010  pm10  pm10_24h    24h   13.0

# %%
df_pm10.describe()
# Out:
#             value
# count  364.000000
# mean    16.590659
# std      8.061063
# min      5.000000
# 25%     11.000000
# 50%     15.000000
# 75%     20.000000
# max     53.000000

# %%
plt.plot(df_pm10['datetime'], df_pm10['value'], color="blue", linewidth=1)

# %%
start_time = pd.to_datetime("08:00:00").time()  # Set start time to 8 am
end_time = pd.to_datetime("18:00:00").time()    # Set end time to 6 pm

# Extract the time component from the datetime
df["time"] = df["datetime"].dt.time

# Filter rows where "time" is between start_time and end_time
df_filtered_working_hours = df[(df["time"] >= start_time) & (df["time"] <= end_time) & (df["core"] == "pm10") ]

df_filtered_working_hours.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       2 end_time = pd.to_datetime("18:00:00").time()    # Set end time to 6 pm
#       4 # Extract the time component from the datetime
#       5 #df["time"] = df["datetime"].dt.time
#       6
#       7 # Filter rows where "time" is between start_time and end_time
# ----> 8 df_filtered_working_hours = df[(df["datetime"] >= start_time) & (df["datetime"] <= end_time) & (df["core"] == "pm10") ]
#      10 df_filtered_working_hours.count()
#
# File ~\anaconda3\envs\basics\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\envs\basics\Lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~\anaconda3\envs\basics\Lib\site-packages\pandas\core\series.py:5799, in Series._cmp_method(self, other, op)
#    5796 lvalues = self._values
#    5797 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5799 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5801 return self._construct_result(res_values, name=res_name)
#
# File ~\anaconda3\envs\basics\Lib\site-packages\pandas\core\ops\array_ops.py:346, in comparison_op(left, right, op)
#     343     return invalid_comparison(lvalues, rvalues, op)
#     345 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 346     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     348 else:
#     349     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\anaconda3\envs\basics\Lib\site-packages\pandas\core\ops\array_ops.py:131, in comp_method_OBJECT_ARRAY(op, x, y)
#     129     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     130 else:
# --> 131     result = libops.scalar_compare(x.ravel(), y, op)
#     132 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'datetime.time'

# %% [markdown]
# Time Series Prediction
# --> train-test split anders, da man nicht Daten der Vergangenheit vorhersagt
#
# streamlit app am Ende programmieren
